# %%
import pandas as pd
import numpy as np

# Example DataFrame
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'Alice', 'Bob'],
    'Age': [25, 30, 35, 28, 32],
    'Salary': [50000, 60000, 70000, 52000, 65000],
    'Department': ['HR', 'IT', 'IT', 'Finance', 'HR']
}
df = pd.DataFrame(data)

# %% [markdown]
# ## Data Exploration

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        5 non-null      object
#  1   Age         5 non-null      int64
#  2   Salary      5 non-null      int64
#  3   Department  5 non-null      object
# dtypes: int64(2), object(2)
# memory usage: 292.0+ bytes

# %%
df.head()
# Out:
#       Name  Age  Salary Department
# 0    Alice   25   50000         HR
# 1      Bob   30   60000         IT
# 2  Charlie   35   70000         IT
# 3    Alice   28   52000    Finance
# 4      Bob   32   65000         HR

# %%
df.tail(2)
# Out:
#     Name  Age  Salary Department
# 3  Alice   28   52000    Finance
# 4    Bob   32   65000         HR

# %%
df.shape
# Out:
# (5, 4)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Salary', 'Department'], dtype='object')

# %%
df.dtypes
# Out:
# Name          object
# Age            int64
# Salary         int64
# Department    object
# dtype: object

# %%
df.describe()
# Out:
#              Age        Salary
# count   5.000000      5.000000
# mean   30.000000  59400.000000
# std     3.807887   8473.488066
# min    25.000000  50000.000000
# 25%    28.000000  52000.000000
# 50%    30.000000  60000.000000
# 75%    32.000000  65000.000000
# max    35.000000  70000.000000
